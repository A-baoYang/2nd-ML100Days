# %% [markdown]
# ### 作業
# 目前已經學過許多的模型，相信大家對整體流程應該比較掌握了，這次作業請改用**手寫辨識資料集**，步驟流程都是一樣的，請試著自己撰寫程式碼來完成所有步驟

# %%
from sklearn import datasets, metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor

# %%
digits = datasets.load_digits()

x_train, x_test, y_train, y_test = train_test_split(digits.data, digits.target, test_size=0.25, random_state=5)

GDBT = GradientBoostingClassifier()

GDBT.fit(x_train, y_train)

y_pred = GDBT.predict(x_test)

# %%
print('Accuracy Score: ', metrics.accuracy_score(y_test, y_pred))
print('Feature Importance: ', GDBT.feature_importances_)
# Out:
# Accuracy Score:  0.9488888888888889
# Feature Importance:  [0.00000000e+00 1.34364951e-05 9.62710535e-03 2.54161691e-03
#  4.45307465e-03 5.36348799e-02 3.23369045e-03 3.86267317e-03
#  0.00000000e+00 4.60281558e-03 1.60371240e-02 1.18415615e-03
#  9.95299763e-03 1.22959247e-02 1.16095425e-03 9.22686574e-04
#  3.20647721e-04 3.96589777e-03 1.02396520e-02 4.63068781e-02
#  2.08875281e-02 8.90692405e-02 8.63988927e-03 6.41000343e-05
#  2.28701745e-04 6.99296137e-04 4.38699332e-02 1.27664216e-02
#  2.56508445e-02 2.62925114e-02 1.57529283e-02 6.52471215e-04
#  0.00000000e+00 7.08060982e-02 5.59132897e-03 6.68809733e-03
#  6.92416419e-02 1.48642783e-02 2.11060712e-02 0.00000000e+00
#  0.00000000e+00 8.60149806e-03 7.85245453e-02 6.69044894e-02
#  1.75131177e-02 1.09612927e-02 2.84565692e-02 4.52835613e-04
#  0.00000000e+00 5.43541572e-04 3.71084546e-03 1.89379549e-02
#  7.59685972e-03 8.59698714e-03 2.80512281e-02 1.66862590e-04
#  7.97916076e-04 4.25444499e-04 1.38861596e-02 1.50588342e-03
#  5.31654770e-02 6.83664960e-03 1.94754291e-02 7.66081990e-03]
