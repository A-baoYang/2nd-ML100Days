# %% [markdown]
# #
#
# # 作業目標:
#
#     1. 藉由固定的 dataset, 來驗證不同loss function
#     2. Dataset 的特性跟我們選用的loss function 對accrancy 的影響
#
#
# # 作業重點:
#     請分別選用 "MSE", "binary _crossentropy"
#     查看Train/test accurancy and loss rate

# %% [markdown]
# # 導入必要的函數

# %%
from keras.datasets import cifar10
import numpy as np
np.random.seed(10)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 資料準備

# %%
#取得Keras Dataset
(x_img_train,y_label_train),(x_img_test,y_label_test)=cifar10.load_data()

# %%
#確認 CIFAR10 Dataset 資料維度
print("train data:",'images:',x_img_train.shape,
      " labels:",y_label_train.shape) 
print("test  data:",'images:',x_img_test.shape ,
      " labels:",y_label_test.shape)
# Out:
# train data: images: (50000, 32, 32, 3)  labels: (50000, 1)
# test  data: images: (10000, 32, 32, 3)  labels: (10000, 1)

# %%
#資料正規化
x_img_train_normalize = x_img_train.astype('float32') / 255.0
x_img_test_normalize = x_img_test.astype('float32') / 255.0

# %%
#針對Label 做 ONE HOT ENCODE
from keras.utils import np_utils
y_label_train_OneHot = np_utils.to_categorical(y_label_train)
y_label_test_OneHot = np_utils.to_categorical(y_label_test)
y_label_test_OneHot.shape
# Out:
# (10000, 10)

# %% [markdown]
# # 建立模型

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D

# %%
model = Sequential()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0714 14:01:48.298471 140478003726208 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
#卷積層1

# %%
model.add(Conv2D(filters=32,kernel_size=(3,3),
                 input_shape=(32, 32,3), 
                 activation='relu', 
                 padding='same'))
# Out:
# W0714 14:01:50.806754 140478003726208 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0714 14:01:50.817361 140478003726208 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.

# %%
model.add(Dropout(rate=0.25))
# Out:
# W0714 14:01:55.804599 140478003726208 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0714 14:01:55.831284 140478003726208 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))
# Out:
# W0714 14:01:57.800524 140478003726208 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
#卷積層2與池化層2

# %%
model.add(Conv2D(filters=64, kernel_size=(3, 3), 
                 activation='relu', padding='same'))

# %%
model.add(Dropout(0.25))

# %%
model.add(MaxPooling2D(pool_size=(2, 2)))

# %%
#建立神經網路(平坦層、隱藏層、輸出層)

# %%
model.add(Flatten())
model.add(Dropout(rate=0.25))

# %%
model.add(Dense(1024, activation='relu'))
model.add(Dropout(rate=0.25))

# %%
model.add(Dense(10, activation='softmax'))

# %%
#檢查model 的STACK
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        896
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 4096)              0
# ...

# %% [markdown]
# # 載入之前訓練的模型

# %%
try:
    model.load_weights("SaveModel/cifarCnnModel.h5")
    print("載入模型成功!繼續訓練模型")
except :    
    print("載入模型失敗!開始訓練一個新模型")
# Out:
# 載入模型失敗!開始訓練一個新模型

# %% [markdown]
# # 訓練模型

# %%
# MSE
model.compile(loss='MSE', optimizer='sgd', metrics=['accuracy'])

# %%
history_MSE = model.fit(x_img_train_normalize, y_label_train_OneHot, validation_split=0.25, epochs=12, batch_size=128, verbose=1)
# Out:
# Train on 37500 samples, validate on 12500 samples
# Epoch 1/12
# 37500/37500 [==============================] - 227s 6ms/step - loss: 0.0904 - acc: 0.1085 - val_loss: 0.0898 - val_acc: 0.1318
# Epoch 2/12
# 37500/37500 [==============================] - 224s 6ms/step - loss: 0.0901 - acc: 0.1086 - val_loss: 0.0897 - val_acc: 0.1395
# Epoch 3/12
# 37500/37500 [==============================] - 224s 6ms/step - loss: 0.0899 - acc: 0.1182 - val_loss: 0.0897 - val_acc: 0.1427
# Epoch 4/12
# 37500/37500 [==============================] - 224s 6ms/step - loss: 0.0898 - acc: 0.1219 - val_loss: 0.0896 - val_acc: 0.1504
# Epoch 5/12
# 37500/37500 [==============================] - 224s 6ms/step - loss: 0.0897 - acc: 0.1262 - val_loss: 0.0895 - val_acc: 0.1573
# Epoch 6/12
# 37500/37500 [==============================] - 223s 6ms/step - loss: 0.0896 - acc: 0.1321 - val_loss: 0.0895 - val_acc: 0.1663
# Epoch 7/12
# ...

# %%
# binary_crossentropy
model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
# Out:
# W0714 14:50:48.021354 140478003726208 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
history_binary_crossentropy = model.fit(x_img_train_normalize, y_label_train_OneHot, validation_split=0.25, epochs=12, batch_size=128, verbose=1)
# Out:
# Train on 37500 samples, validate on 12500 samples
# Epoch 1/12
# 37500/37500 [==============================] - 115s 3ms/step - loss: 0.3172 - acc: 0.9000 - val_loss: 0.3167 - val_acc: 0.9000
# Epoch 2/12
# 37500/37500 [==============================] - 115s 3ms/step - loss: 0.3129 - acc: 0.9000 - val_loss: 0.3129 - val_acc: 0.9000
# Epoch 3/12
# 37500/37500 [==============================] - 115s 3ms/step - loss: 0.3074 - acc: 0.9000 - val_loss: 0.3081 - val_acc: 0.9000
# Epoch 4/12
# 37500/37500 [==============================] - 115s 3ms/step - loss: 0.3017 - acc: 0.9001 - val_loss: 0.3037 - val_acc: 0.9000
# Epoch 5/12
# 37500/37500 [==============================] - 115s 3ms/step - loss: 0.2970 - acc: 0.9002 - val_loss: 0.2994 - val_acc: 0.9000
# Epoch 6/12
# 37500/37500 [==============================] - 115s 3ms/step - loss: 0.2935 - acc: 0.9004 - val_loss: 0.2966 - val_acc: 0.9000
# Epoch 7/12
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

#定義一個繪圖函數
def show_train_history(train_history, train_acc, test_acc):
    plt.plot(train_history.history[train_acc])
    plt.plot(train_history.history[test_acc])
    plt.title('Train History')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train_acc', 'val_acc'], loc='upper left')
    plt.show()

# %%
show_train_history(history_MSE, 'acc', 'val_acc')

# %%
show_train_history(history_binary_crossentropy, 'acc', 'val_acc')
